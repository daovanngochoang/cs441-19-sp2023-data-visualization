# %%
import pandas as pd
import yfinance as yf
from datetime import datetime
import plotly.express as px
import pandas as pd

# %%
# Use pandas to read the CSV file containing all available symbols
symbol_list = pd.read_csv('https://raw.githubusercontent.com/shilewenuw/get_all_tickers/master/get_all_tickers/tickers.csv')

# %%
amzn = yf.Ticker('GOOG')

price = amzn.info
print(price)


# GET TODAYS DATE AND CONVERT IT TO A STRING WITH YYYY-MM-DD FORMAT (YFINANCE EXPECTS THAT FORMAT)
end_date = datetime.now().strftime('%Y-%m-%d')
amzn_hist = amzn.history(start='2018-01-01',end='2019-12-30')
amzn_hist
amzn_hist.reset_index()
# Out:
# {'symbol': 'GOOG', 'twoHundredDayAverageChangePercent': 0.025500342, 'fiftyTwoWeekLowChangePercent': 0.25158307, 'averageAnalystRating': '1.5 - Strong Buy', 'language': 'en-US', 'earningsTimestampEnd': 1682712000, 'regularMarketDayRange': '104.22 - 106.525', 'epsForward': 6.06, 'regularMarketDayHigh': 106.525, 'twoHundredDayAverageChange': 2.597145, 'twoHundredDayAverage': 101.84746, 'askSize': 12, 'bookValue': 19.935, 'marketCap': 1337580191744, 'fiftyTwoWeekHighChange': -35.403893, 'fiftyTwoWeekRange': '83.45 - 139.8485', 'fiftyDayAverageChange': 6.2470016, 'averageDailyVolume3Month': 32396877, 'exchangeDataDelayedBy': 0, 'firstTradeDateMilliseconds': 1092922200000, 'trailingAnnualDividendRate': 0.0, 'fiftyTwoWeekLow': 83.45, 'regularMarketVolume': 7918611, 'market': 'us_market', 'quoteSourceName': 'Nasdaq Real Time Price', 'messageBoardId': 'finmb_29096', 'priceHint': 2, 'regularMarketDayLow': 104.22, 'exchange': 'NMS', 'sourceInterval': 15, 'shortName': 'Alphabet Inc.', 'region':
# ...

# %%
px.line(amzn_hist.reset_index(), x="Date", y="Close")

# %%
companies = ['AMZN','GOOG','MSFT','TSLA','META'] 
tickers = yf.Tickers(companies)
tickers_hist = tickers.history(period='max',end=end_date,interval='1m',)
tickers_hist
# Out:
# [*********************100%***********************]  5 of 5 completed
#                                 Close                                      \
#                                  AMZN        GOOG        META        MSFT
# Datetime
# 2023-03-29 09:30:00-04:00   99.239998  102.180000  202.929993  278.570007
# 2023-03-29 09:31:00-04:00   99.269997  102.279999  203.050003  278.950012
# 2023-03-29 09:32:00-04:00   99.434998  102.526497  203.640106  279.445007
# 2023-03-29 09:33:00-04:00   99.260002  102.470001  203.770004  279.334991
# 2023-03-29 09:34:00-04:00   99.358200  102.464996  203.770004  279.429993
# ...                               ...         ...         ...         ...
# 2023-04-04 15:55:00-04:00  103.899696  104.959999  214.600006  286.799988
# 2023-04-04 15:56:00-04:00  103.879997  105.044998  214.699997  286.929993
# 2023-04-04 15:57:00-04:00  103.959999  105.019997  214.580002  287.049988
# 2023-04-04 15:58:00-04:00  103.875000  105.059998  214.360001  286.899994
# ...

# %% [markdown]
# ## Questions.
# According to the stock data  provided by yahoo, select data of big tech companies such as AMAZON, GOOGLE, TESLA, META.
# 1. What stock has largest trading volume
# 2. During the covid 19 what stock has highest rate of going up
# 3. During the hard time of global finance scenery, what stock has the highest fluctuate rate.
# 4. How the event of releasing new ChatGPT AI affect to the GOOGLE and Microsoft stock.

# %%
amzn_hist.reset_index()
# Out:
#                          Date        Open        High         Low       Close  \
# 0   2022-01-03 00:00:00-05:00  167.550003  170.703506  166.160507  170.404495
# 1   2022-01-04 00:00:00-05:00  170.438004  171.399994  166.349503  167.522003
# 2   2022-01-05 00:00:00-05:00  166.882996  167.126495  164.356995  164.356995
# 3   2022-01-06 00:00:00-05:00  163.450500  164.800003  161.936996  163.253998
# 4   2022-01-07 00:00:00-05:00  163.839005  165.243500  162.031006  162.554001
# ..                        ...         ...         ...         ...         ...
# 310 2023-03-29 00:00:00-04:00   98.690002  100.419998   98.559998  100.250000
# 311 2023-03-30 00:00:00-04:00  101.550003  103.040001  101.010002  102.000000
# 312 2023-03-31 00:00:00-04:00  102.160004  103.489998  101.949997  103.290001
# 313 2023-04-03 00:00:00-04:00  102.300003  103.290001  101.430000  102.410004
# 314 2023-04-04 00:00:00-04:00  102.750000  104.199997  102.110001  103.949997
#
# ...

# %%
px.line(amzn_hist.reset_index(), y="Close", x="Date")

# %%
close_price = tickers_hist.Close
close_price.reset_index()
# Out:
#                       Datetime        AMZN        GOOG        META  \
# 0    2023-03-29 09:30:00-04:00   99.239998  102.180000  202.929993
# 1    2023-03-29 09:31:00-04:00   99.269997  102.279999  203.050003
# 2    2023-03-29 09:32:00-04:00   99.434998  102.526497  203.640106
# 3    2023-03-29 09:33:00-04:00   99.260002  102.470001  203.770004
# 4    2023-03-29 09:34:00-04:00   99.358200  102.464996  203.770004
# ...                        ...         ...         ...         ...
# 1944 2023-04-04 15:55:00-04:00  103.899696  104.959999  214.600006
# 1945 2023-04-04 15:56:00-04:00  103.879997  105.044998  214.699997
# 1946 2023-04-04 15:57:00-04:00  103.959999  105.019997  214.580002
# 1947 2023-04-04 15:58:00-04:00  103.875000  105.059998  214.360001
# 1948 2023-04-04 15:59:00-04:00  104.000000  105.139999  214.720001
#
#             MSFT        TSLA
# 0     278.570007  193.620804
# 1     278.950012  193.660004
# 2     279.445007  193.699997
# 3     279.334991  194.179993
# ...

# %%
companies = ['AMZN','GOOG','MSFT','META'] 
tickers = yf.Tickers(companies)

end_date = datetime.now().strftime('%Y-%m-%d')
start_date = "2017-12-01"
tickers_hist = tickers.history(start=start_date, end=end_date)
tickers_hist
# Out:
# [*********************100%***********************]  5 of 5 completed
#                  Close                                                  \
#                   AMZN        GOOG        META        MSFT        TSLA
# Date
# 2017-12-01   58.117500   50.508499  175.100006   79.150650   20.435333
# 2017-12-04   56.697498   49.933998  171.470001   76.163467   20.346666
# 2017-12-05   57.078499   50.257500  172.830002   76.642548   20.246668
# 2017-12-06   57.617500   50.918999  176.059998   77.760384   20.884001
# 2017-12-07   57.989498   51.546501  180.139999   77.487961   20.749332
# ...                ...         ...         ...         ...         ...
# 2023-03-29  100.250000  101.900002  205.350006  280.510010  193.880005
# 2023-03-30  102.000000  101.320000  207.839996  284.049988  195.279999
# 2023-03-31  103.290001  104.000000  211.940002  288.299988  207.460007
# 2023-04-03  102.410004  104.910004  213.070007  287.230011  194.770004
# ...

# %%
# tickers.news()

# %%
px.line(tickers_hist.Close.reset_index(), y=companies, x="Date")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 px.line(tickers_hist.Close.reset_index(), y=companies, x="Date")
#
# NameError: name 'tickers_hist' is not defined

# %%
px.line(tickers_hist.Volume.reset_index(), y=companies, x="Date")

# %% [markdown]
# ## Functions

# %%
class StockReader:
    def __init__(self, company_symbols: list, start_date: str = None, end_date: str = None) -> None:
        print("CONNECT AND FETCH DATA ...")
        self.__stock_price_data = self.__read_data(
            company_symbols, start_date, end_date)
            
        self.__current_symbols = company_symbols
        self.__start_date = start_date
        self.__end_date = end_date
        self.info = {}
        self.__get_info()
        self.stock_price = self.__stock_price_data
        
        
    def __get_info(self):
        for symbol in self.__current_symbols:
            print(f'fetching data of {symbol}')
            self.info[symbol] = yf.Ticker(symbol).info
    

    def __read_data(self, company_symbols, start_date=None, end_date=None):
        start = start_date if start_date != None else "2006-01-01"
        end = end_date if end_date != None else datetime.now().strftime('%Y-%m-%d')

        tickers = yf.Tickers(company_symbols)

        tickers_hist = tickers.history(start=start, end=end)

        return tickers_hist

    def __draw(self, df):
        px.line(df.reset_index(), y=companies, x="Date").show()

    def draw_close_price(self):
        self.__draw(self.__stock_price_data.Close)

    def draw_volume(self):
        self.__draw(self.__stock_price_data.Volume)

    def draw_high_price(self):
        self.__draw(self.__stock_price_data.High)

    def draw_low_price(self):
        self.__draw(self.__stock_price_data.Low)

    def draw_price_fluctuate(self, start_date, end_date):
        pass

# %%
companies = ['AMZN','GOOG','MSFT','META'] 
start_date = "2020-01-01"


stock_reader = StockReader(companies, start_date=start_date)
# Out:
# CONNECT AND FETCH DATA ...
# [*********************100%***********************]  4 of 4 completed
# fetching data of AMZN
# fetching data of GOOG
# fetching data of MSFT
# fetching data of META

# %%
stock_reader.draw_close_price()

# %%
stock_reader.draw_high_price()

# %%
stock_reader.draw_volume()

# %%
data = {'symbol': [],
        'twoHundredDayAverageChangePercent': [],
        'averageAnalystRating': [],
        'fiftyTwoWeekLowChangePercent': [],
        'language': [],
        'preMarketChangePercent': [],
        'regularMarketDayRange': [],
        'earningsTimestampEnd': [],
        'epsForward': [],
        'regularMarketDayHigh': [],
        'twoHundredDayAverageChange': [],
        'twoHundredDayAverage': [],
        'askSize': [],
        'bookValue': [],
        'fiftyTwoWeekHighChange': [],
        'marketCap': [],
        'fiftyTwoWeekRange': [],
        'fiftyDayAverageChange': [],
        'firstTradeDateMilliseconds': [],
        'averageDailyVolume3Month': [],
        'exchangeDataDelayedBy': [],
        'trailingAnnualDividendRate': [],
        'fiftyTwoWeekLow': [],
        'market': [],
        'regularMarketVolume': [],
        'quoteSourceName': [],
        'messageBoardId': [],
        'priceHint': [],
        'sourceInterval': [],
        'exchange': [],
        'regularMarketDayLow': [],
        'shortName': [],
        'region': [],
        'fiftyDayAverageChangePercent': [],
        'preMarketTime': [],
        'fullExchangeName': [],
        'earningsTimestampStart': [],
        'financialCurrency': [],
        'displayName': [],
        'gmtOffSetMilliseconds': [],
        'regularMarketOpen': [],
        'regularMarketTime': [],
        'regularMarketChangePercent': [],
        'quoteType': [],
        'trailingAnnualDividendYield': [],
        'fiftyTwoWeekLowChange': [],
        'averageDailyVolume10Day': [],
        'fiftyTwoWeekHighChangePercent': [],
        'typeDisp': [],
        'tradeable': [],
        'preMarketPrice': [],
        'currency': [],
        'sharesOutstanding': [],
        'fiftyTwoWeekHigh': [],
        'regularMarketPreviousClose': [],
        'exchangeTimezoneName': [],
        'bidSize': [],
        'regularMarketChange': [],
        'priceEpsCurrentYear': [],
        'cryptoTradeable': [],
        'fiftyDayAverage': [],
        'epsCurrentYear': [],
        'exchangeTimezoneShortName': [],
        'regularMarketPrice': [],
        'customPriceAlertConfidence': [],
        'marketState': [],
        'preMarketChange': [],
        'forwardPE': [],
        'earningsTimestamp': [],
        'ask': [],
        'epsTrailingTwelveMonths': [],
        'bid': [],
        'triggerable': [],
        'priceToBook': [],
        'longName': [],
        'trailingPegRatio': []
        }

# %%
def read_data(symbols):
    for symbol in symbols:
        print(symbol)
        raw_data = yf.Ticker(symbol).info
        for field in data:
            data[field].append(raw_data[field])

# %%
read_data(companies)
df = pd.DataFrame(data)
# Out:
# AMZN
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 read_data(companies)
#       2 df = pd.DataFrame(data)
#
# Cell In[23], line 6, in read_data(symbols)
#       4 raw_data = yf.Ticker(symbol).info
#       5 for field in data:
# ----> 6     data[field].append(raw_data[field])
#
# KeyError: 'preMarketChangePercent'

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
yf.Ticker("AMZN").info
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 yf.Ticker("AMZN").info
#
# NameError: name 'yf' is not defined

# %%
df = pd.DataFrame(data=data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[100], line 1
# ----> 1 df = pd.DataFrame(data=data)
#
# File ~/Programs/anaconda3/envs/bigdata/lib/python3.9/site-packages/pandas/core/frame.py:664, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     658     mgr = self._init_mgr(
#     659         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     660     )
#     662 elif isinstance(data, dict):
#     663     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 664     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     665 elif isinstance(data, ma.MaskedArray):
#     666     import numpy.ma.mrecords as mrecords
#
# File ~/Programs/anaconda3/envs/bigdata/lib/python3.9/site-packages/pandas/core/internals/construction.py:493, in dict_to_mgr(data, index, columns, dtype, typ, copy)
# ...

# %%
import requests

# Make a request to the API endpoint
response = requests.get("https://disease.sh/v3/covid-19/all")

# Print the JSON response
print(response.json())
# Out:
# {'updated': 1680704331729, 'cases': 684317088, 'todayCases': 42336, 'deaths': 6833935, 'todayDeaths': 125, 'recovered': 657277423, 'todayRecovered': 73355, 'active': 20205730, 'critical': 39823, 'casesPerOneMillion': 87792, 'deathsPerOneMillion': 876.7, 'tests': 6965383930, 'testsPerOneMillion': 876707.46, 'population': 7944935131, 'oneCasePerPeople': 0, 'oneDeathPerPeople': 0, 'oneTestPerPeople': 0, 'activePerOneMillion': 2543.22, 'recoveredPerOneMillion': 82729.11, 'criticalPerOneMillion': 5.01, 'affectedCountries': 231}

# %%
import requests
import pandas as pd

# set start and end dates
start_date = '2019-03-01'
end_date = '2022-03-31'

# make API request
url = f'https://data.cdc.gov/resource/9mfq-cb36.json?$where=submission_date between "{start_date}" and "{end_date}"'
response = requests.get(url)

# convert response to Pandas DataFrame
df = pd.DataFrame(response.json())

# print first 5 rows of DataFrame
# print(df.head())
df
# Out:
#              submission_date state tot_cases conf_cases prob_cases new_case  \
# 0    2021-03-11T00:00:00.000    KS    297229   241035.0      56194      0.0
# 1    2021-12-01T00:00:00.000    ND    163565   135705.0      27860    589.0
# 2    2022-01-02T00:00:00.000    AS        11        NaN        NaN      0.0
# 3    2021-11-22T00:00:00.000    AL    841461   620483.0     220978    703.0
# 4    2020-05-17T00:00:00.000   RMI         0        0.0          0      0.0
# ..                       ...   ...       ...        ...        ...      ...
# 995  2021-02-03T00:00:00.000    OH    906727   788126.0     118601   3991.0
# 996  2021-11-12T00:00:00.000    IA    503564        NaN        NaN   3090.0
# 997  2022-01-16T00:00:00.000    AS        11        NaN        NaN      0.0
# 998  2020-09-25T00:00:00.000    MP        69       69.0          0      0.0
# 999  2020-05-12T00:00:00.000    NY    152362        NaN        NaN    664.0
#
# ...

# %%
import requests

start_date = '2019-01-01'
end_date = '2023-01-01'

url = f'https://api.covid19api.com/world?from={start_date}T00:00:00Z&to={end_date}T23:59:59Z'

response = requests.get(url)
data = response.json()

# convert response to Pandas DataFrame
df = pd.DataFrame(response.json())

# %%
df.tail()
# Out:
#      NewConfirmed  TotalConfirmed  NewDeaths  TotalDeaths  NewRecovered  \
# 551        346231       628388944       1369      6582567             0
# 552        692434       580643430       2202      6407482             0
# 553        234376       187007753       3755      4036516        130926
# 554       1035892       412877082       6529      5822100             0
# 555        305218       509584464       3375      6220252             0
#
#      TotalRecovered                      Date
# 551               0   2022-10-29T23:57:02.77Z
# 552               0  2022-08-05T23:24:18.083Z
# 553       123426302  2021-07-13T22:54:19.604Z
# 554               0  2022-02-15T22:56:01.573Z
# 555               0   2022-04-27T21:49:18.28Z

# %%
import plotly.express as px
import pandas as pd
px.bar(df, x="Date", y="NewConfirmed")

# %%
import requests
import pandas as pd

# Set the API endpoint URL
url = 'https://disease.sh/v3/covid-19/historical/all?lastdays=10000'

# Send a GET request to the API endpoint
response = requests.get(url)

response.json()


# Parse the JSON response into a pandas DataFrame
data = pd.DataFrame.from_dict(response.json()['deaths'], orient='index')


# Convert the date strings to datetime objects
data.index = pd.to_datetime(data.index)


# Filter the data to include only the dates from 2019 to 2022
data = data.loc['2019-01-01':'2022-12-31']


# # Calculate the daily new cases by taking the difference between adjacent rows
data['new_deaths'] = data.diff().fillna(0)
data

# Print the resulting DataFrame
data.index.name = "Date"
data = data.reset_index()
data
# Out:
#            Date        0  new_deaths
# 0    2020-01-22       17         0.0
# 1    2020-01-23       18         1.0
# 2    2020-01-24       26         8.0
# 3    2020-01-25       42        16.0
# 4    2020-01-26       56        14.0
# ...         ...      ...         ...
# 1070 2022-12-27  6684351      2104.0
# 1071 2022-12-28  6687147      2796.0
# 1072 2022-12-29  6690067      2920.0
# 1073 2022-12-30  6692483      2416.0
# 1074 2022-12-31  6693376       893.0
#
# [1075 rows x 3 columns]

# %%
import pandas as pd
import yfinance as yf
from datetime import datetime
import plotly.express as px
import pandas as pd

# %%
px.line(data, y='new_deaths', x="Date")

# %%
import requests
import pandas as pd

# Set the API endpoint URL
url = 'https://disease.sh/v3/covid-19/historical/all?lastdays=1000'

# Send a GET request to the API endpoint
response = requests.get(url)

# Parse the JSON response into a pandas DataFrame
data = pd.DataFrame.from_dict(response.json()['deaths'], orient='index')

# Convert the date strings to datetime objects
data.index = pd.to_datetime(data.index)

# Filter the data to include only the dates from 2019 to 2022
data = data.loc['2019-01-01':'2022-12-31']

# Calculate the daily new deaths by taking the difference between adjacent rows
data['new_deaths'] = data.diff().fillna(0)

# Print the resulting DataFrame
print(data)
# Out:
#                   0  new_deaths
# 2020-06-13   468056         0.0
# 2020-06-14   471838      3782.0
# 2020-06-15   475905      4067.0
# 2020-06-16   483023      7118.0
# 2020-06-17   488500      5477.0
# ...             ...         ...
# 2022-12-27  6684351      2104.0
# 2022-12-28  6687147      2796.0
# 2022-12-29  6690067      2920.0
# 2022-12-30  6692483      2416.0
# 2022-12-31  6693376       893.0
#
# [932 rows x 2 columns]

# %%
import plotly.graph_objects as go

# create first trace
trace1 = go.Scatter(
    x=[1, 2, 3],
    y=[4, 5, 6],
    name='Trace 1'
)

# create second trace
trace2 = go.Scatter(
    x=[1, 2, 3],
    y=[10, 11, 12],
    name='Trace 2',
    yaxis='y2'
)

# create layout with 2 y-axes
layout = go.Layout(
    title='Two Traces with Different Y-Axes',
    yaxis=dict(
        title='Trace 1'
    ),
    yaxis2=dict(
        title='Trace 2',
        overlaying='y',
        side='right'
    )
)

# create figure with both traces and layout
fig = go.Figure(data=[trace1, trace2], layout=layout)

# show figure
fig.show()

# %%
import yfinance as yf
import matplotlib.pyplot as plt

ticker = "MSFT"
start_date = "2019-01-01"
end_date = "2023-01-01"

data = yf.download(ticker, start=start_date, end=end_date)
prices = data["Adj Close"]

plt.plot(prices)
plt.title(f"{ticker} Price Change from {start_date} to {end_date}")
plt.xlabel("Date")
plt.ylabel("Price")
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
import plotly.graph_objs as go
from plotly.subplots import make_subplots
import yfinance as yf

# Get MSFT data from Yahoo Finance
msft = yf.Ticker("MSFT")
data = msft.history(start="2019-01-01", end="2023-01-01")

# Create a figure with two subplots
fig = make_subplots(rows=2, cols=0)

# Add the first subplot
fig.add_trace(
    go.Scatter(x=data.index, y=data["Close"], name="MSFT Close"),
    row=1,
    col=0
)

# Add the second subplot
fig.add_trace(
    go.Scatter(x=data.index, y=data["Volume"], name="MSFT Volume"),
    row=2,
    col=0
)

# Update the layout of the figure
fig.update_layout(title="MSFT Stock Data", height=500, width=1000)

# Show the figure
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 10
#       7 data = msft.history(start="2019-01-01", end="2023-01-01")
#       9 # Create a figure with two subplots
# ---> 10 fig = make_subplots(rows=2, cols=0)
#      12 # Add the first subplot
#      13 fig.add_trace(
#      14     go.Scatter(x=data.index, y=data["Close"], name="MSFT Close"),
#      15     row=1,
#      16     col=0
#      17 )
#
# File ~/Programs/anaconda3/envs/bigdata/lib/python3.9/site-packages/plotly/subplots.py:305, in make_subplots(rows, cols, shared_xaxes, shared_yaxes, start_cell, print_grid, horizontal_spacing, vertical_spacing, subplot_titles, column_widths, row_heights, specs, insets, column_titles, row_titles, x_title, y_title, figure, **kwargs)
#       7 def make_subplots(
#       8     rows=1,
#       9     cols=1,
#    (...)
#      26     **kwargs,
#      27 ) -> go.Figure:
# ...

# %%
import plotly.graph_objs as go
import yfinance as yf

# Get Microsoft stock data from Yahoo Finance
msft = yf.Ticker("MSFT")
data = msft.history(period="5y")

# Create trace for the closing price data
trace1 = go.Scatter(x=data.index, y=data['Close'], name="MSFT Close")

# Create trace for the volume data
trace2 = go.Bar(x=data.index, y=data['Volume'], name="MSFT Volume")

# Create layout for the figure
layout = go.Layout(title="Microsoft Stock Data",
                   xaxis=dict(title="Date"),
                   yaxis=dict(title="Price"),
                   plot_bgcolor='black',
                   paper_bgcolor='black')

# Create figure object with the data and layout
fig = go.Figure(data=[trace1, trace2], layout=layout)

# Show the figure
fig.show()

# %%
import yfinance as yf
import plotly.graph_objs as go

# Get MSFT data from 2019 to 2023
msft = yf.Ticker("MSFT")
msft_data = msft.history(start="2019-01-01", end="2023-01-01")

# Create a trace for MSFT close price
msft_trace = go.Line(x=msft_data.index, y=msft_data["Close"], name="MSFT")

# Create a layout with a black background
layout = go.Layout(
    paper_bgcolor="black",
    plot_bgcolor="black",
    font=dict(color="white")
)

# Create a figure with the MSFT trace and layout
fig = go.Figure(msft_trace, layout=layout)

# Display the figure
fig.show()
# Out:
# /home/andreas/Programs/anaconda3/envs/bigdata/lib/python3.9/site-packages/plotly/graph_objs/_deprecations.py:378: DeprecationWarning:
#
# plotly.graph_objs.Line is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.scatter.Line
#   - plotly.graph_objs.layout.shape.Line
#   - etc.
